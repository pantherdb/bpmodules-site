# %%
import json
import gzip
from os import path as ospath
import pandas as pd
import numpy as np
import random
import pprint
from src.utils import write_to_json
terms_fp = './downloads/input/go_term_info.json'
genes_fp = './downloads/input/bp_module_gene_info.json'
term_dispositions_fp = './downloads/input/term_dispositions.json'
ibd_modules_fp = './downloads/input/ibd_modules_organized.json'

clean_ibd_modules_fp = './downloads/input/clean_ibd_modules.json'


unknown_terms =['UNKNOWN:0001', 'UNKNOWN:0002', 'UNKNOWN:0003']

# %%
def get_pd_row(df, k):
    return dict(df.loc[k].dropna())

def spread_terms(df, terms):
    return [get_pd_row(df, term) for term in terms]

def get_pd_row_key(df, k):
    try:
        return dict(df.loc[k].dropna())
    except KeyError:
        return None

# %%
terms_df = pd.read_json(terms_fp)
terms_df = terms_df.set_index('term_id', drop=False)
terms_df = terms_df.rename(columns={'term_id': 'id', 'term_label': 'label'})
terms_df
# Out:
#                     id                                              label
# term_id
# GO:0042552  GO:0042552                                        myelination
# GO:0045065  GO:0045065                   cytotoxic T cell differentiation
# GO:0001992  GO:0001992  regulation of systemic arterial blood pressure...
# GO:0048247  GO:0048247                              lymphocyte chemotaxis
# GO:0045954  GO:0045954  positive regulation of natural killer cell med...
# ...                ...                                                ...
# OTHER:0008  OTHER:0008                             other circadian rhythm
# OTHER:0009  OTHER:0009                            other metabolic process
# OTHER:0010  OTHER:0010                               other system process
# OTHER:0011  OTHER:0011                             other cellular process
# OTHER:0012  OTHER:0012             other anatomical structure development
#
# [2015 rows x 2 columns]

# %%
term_dispositions_df = pd.read_json(term_dispositions_fp)
term_dispositions_df = term_dispositions_df.rename(columns={'term_id': 'id', 'affected_term_id': 'target_id'})
term_dispositions_df = term_dispositions_df.set_index('id', drop=False)

term_dispositions_df
# Out:
#                     id disposition   target_id
# id
# GO:0001818  GO:0001818    negative  GO:0001816
# GO:0001915  GO:0001915    negative  GO:0001913
# GO:0001916  GO:0001916    positive  GO:0001913
# GO:0001938  GO:0001938    positive  GO:0001935
# GO:0001953  GO:0001953    negative  GO:0007160
# ...                ...         ...         ...
# GO:1904262  GO:1904262    negative  GO:0038202
# GO:1904263  GO:1904263    positive  GO:0038202
# GO:1903036  GO:1903036    positive  GO:0009611
# GO:1903070  GO:1903070    negative  GO:0030433
# GO:1903142  GO:1903142    positive  GO:0061028
#
# [317 rows x 3 columns]

# %%
genes_df = pd.read_json(genes_fp, dtype={'taxon_id':str})
genes_df = genes_df.set_index('gene', drop=False)
genes_df
# Out:
#                               gene gene_symbol  \
# gene
# UniProtKB:Q8IWV8  UniProtKB:Q8IWV8        UBR2
# UniProtKB:Q96D42  UniProtKB:Q96D42      HAVCR1
# UniProtKB:Q96RW7  UniProtKB:Q96RW7       HMCN1
# UniProtKB:P37059  UniProtKB:P37059     HSD17B2
# UniProtKB:Q8WXG6  UniProtKB:Q8WXG6        MADD
# ...                            ...         ...
# UniProtKB:Q9H3U5  UniProtKB:Q9H3U5       MFSD1
# UniProtKB:O94989  UniProtKB:O94989    ARHGEF15
# UniProtKB:O00458  UniProtKB:O00458       IFRD1
# UniProtKB:Q96I25  UniProtKB:Q96I25       RBM17
# UniProtKB:Q6NXT2  UniProtKB:Q6NXT2        H3-5
#
#                                                           gene_name taxon_id  \
# gene
# UniProtKB:Q8IWV8                   E3 ubiquitin-protein ligase UBR2     9606
# UniProtKB:Q96D42              Hepatitis A virus cellular receptor 1     9606
# UniProtKB:Q96RW7                                       Hemicentin-1     9606
# UniProtKB:P37059        17-beta-hydroxysteroid dehydrogenase type 2     9606
# UniProtKB:Q8WXG6         MAP kinase-activating death domain protein     9606
# ...                                                             ...      ...
# UniProtKB:Q9H3U5  Major facilitator superfamily domain-containin...     9606
# UniProtKB:O94989          Rho guanine nucleotide exchange factor 15     9606
# UniProtKB:O00458       Interferon-related developmental regulator 1     9606
# UniProtKB:Q96I25                                 Splicing factor 45     9606
# UniProtKB:Q6NXT2                                      Histone H3.3C     9606
#
#                   panther_family  long_id
# gene
# UniProtKB:Q8IWV8             NaN      NaN
# UniProtKB:Q96D42             NaN      NaN
# UniProtKB:Q96RW7             NaN      NaN
# UniProtKB:P37059             NaN      NaN
# UniProtKB:Q8WXG6             NaN      NaN
# ...                          ...      ...
# UniProtKB:Q9H3U5             NaN      NaN
# UniProtKB:O94989             NaN      NaN
# UniProtKB:O00458             NaN      NaN
# UniProtKB:Q96I25             NaN      NaN
# UniProtKB:Q6NXT2             NaN      NaN
#
# [16350 rows x 6 columns]

# %%
ibd_modules_df = pd.read_json(ibd_modules_fp)

ibd_modules_df
# Out:
#             id                                         categories
# 0   GO:0071840  [{'id': 'GO:0034330', 'modules': [{'module_ter...
# 1   GO:0051179  [{'id': 'OTHER:0003', 'modules': [{'module_ter...
# 2   GO:0050896  [{'id': 'GO:0007165', 'modules': [{'module_ter...
# 3   GO:0002376  [{'id': 'OTHER:0005', 'modules': [{'module_ter...
# 4   GO:0010817  [{'id': 'OTHER:0006', 'modules': [{'module_ter...
# 5   GO:0042592  [{'id': 'OTHER:0007', 'modules': [{'module_ter...
# 6   GO:0007623  [{'id': 'OTHER:0008', 'modules': [{'module_ter...
# 7   GO:0008152  [{'id': 'GO:0006259', 'modules': [{'module_ter...
# 8   GO:0003008  [{'id': 'GO:0003013', 'modules': [{'module_ter...
# 9   GO:0009987  [{'id': 'GO:0007155', 'modules': [{'module_ter...
# 10  GO:0048856  [{'id': 'OTHER:0012', 'modules': [{'module_ter...
# 11  OTHER:0001  [{'id': 'GO:0007548', 'modules': [{'module_ter...

# %%
def enrich_json_data(data, terms_df, genes_df):
    for entry in data:
        entry['label']= get_pd_row(terms_df, entry['id'])['label']
        entry['category_count']= len(entry["categories"])
        for category in entry.get("categories", []):
            # Add category label
            category_id = category.get("id")
            category["category_label"] = get_pd_row(terms_df, category_id)['label']
            category['module_count']= len(category["modules"])

            for module in category.get("modules", []):
                module_term_id = module.get("module_term")
                module["module_term_label"] = terms_df.loc[module_term_id, 'label'] if module_term_id in terms_df.index else None
                nodes = module.get("nodes", [])
                module['nodes_count']= len(nodes)
                for node in nodes:
                    node['terms'] = [{'term_id': term, 'term_label': terms_df.loc[term, 'label']} for term in node.get('terms', []) if term in terms_df.index]
                    node['leaf_genes'] = [genes_df.loc[gene].to_dict() for gene in node.get('leaf_genes', []) if gene in genes_df.index]
                   

with open(ibd_modules_fp, 'r') as file:
    json_data = json.load(file)


# Call the function to enrich the JSON data
enrich_json_data(json_data, terms_df, genes_df)

# Output the enriched JSON data
print(json.dumps(json_data[:1], indent=2))

#json_str = json.loads(json_data)
write_to_json(json_data, ospath.join(clean_ibd_modules_fp), indent=2)
# Out:
# [
#   {
#     "id": "GO:0071840",
#     "categories": [
#       {
#         "id": "GO:0034330",
#         "modules": [
#           {
#             "module_term": "GO:0120192",
#             "nodes": [
#               {
#                 "ptn_id": "PTN007679700",
#                 "label": "PATJ HOMOLOG",
#                 "terms": [
#                   {
#                     "term_id": "GO:0120192",
#                     "term_label": "tight junction assembly"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:O75970",
#                     "gene_symbol": "MPDZ",
#                     "gene_name": "Multiple PDZ domain protein",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   },
#                   {
#                     "gene": "UniProtKB:Q8NI35",
#                     "gene_symbol": "PATJ",
#                     "gene_name": "InaD-like protein",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN002698193",
#                 "label": "LIPOLYSIS-STIMULATED LIPOPROTEIN RECEPTOR",
#                 "terms": [
#                   {
#                     "term_id": "GO:1904274",
#                     "term_label": "tricellular tight junction assembly"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:Q86X29",
#                     "gene_symbol": "LSR",
#                     "gene_name": "Lipolysis-stimulated lipoprotein receptor",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN002731222",
#                 "label": "PROTEIN POF1B",
#                 "terms": [
#                   {
#                     "term_id": "GO:0070830",
#                     "term_label": "bicellular tight junction assembly"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:Q8WVV4",
#                     "gene_symbol": "POF1B",
#                     "gene_name": "Protein POF1B",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN000462700",
#                 "label": "FERM AND PDZ DOMAIN-CONTAINING PROTEIN 2",
#                 "terms": [
#                   {
#                     "term_id": "GO:0070830",
#                     "term_label": "bicellular tight junction assembly"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:Q68DX3",
#                     "gene_symbol": "FRMPD2",
#                     "gene_name": "FERM and PDZ domain-containing protein 2",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN004555956",
#                 "label": "MARVEL DOMAIN-CONTAINING PROTEIN 3",
#                 "terms": [
#                   {
#                     "term_id": "GO:0070830",
#                     "term_label": "bicellular tight junction assembly"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:Q96A59",
#                     "gene_symbol": "MARVELD3",
#                     "gene_name": "MARVEL domain-containing protein 3",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN000974682",
#                 "label": "TUBULIN-SPECIFIC CHAPERONE D",
#                 "terms": [
#                   {
#                     "term_id": "GO:0070830",
#                     "term_label": "bicellular tight junction assembly"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:Q9BTW9",
#                     "gene_symbol": "TBCD",
#                     "gene_name": "Tubulin-specific chaperone D",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN002760875",
#                 "label": "OCCLUDIN",
#                 "terms": [
#                   {
#                     "term_id": "GO:0070830",
#                     "term_label": "bicellular tight junction assembly"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:Q16625",
#                     "gene_symbol": "OCLN",
#                     "gene_name": "Occludin",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN000243505",
#                 "label": "CLAUDIN",
#                 "terms": [
#                   {
#                     "term_id": "GO:0070830",
#                     "term_label": "bicellular tight junction assembly"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:H7C241",
#                     "gene_symbol": "CLDN34",
#                     "gene_name": "Claudin-34",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   },
#                   {
#                     "gene": "UniProtKB:Q96B33",
#                     "gene_symbol": "CLDN23",
#                     "gene_name": "Claudin-23",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   },
#                   {
#                     "gene": "UniProtKB:O00501",
#                     "gene_symbol": "CLDN5",
#                     "gene_name": "Claudin-5",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   },
#                   {
#                     "gene": "UniProtKB:P56750",
#                     "gene_symbol": "CLDN17",
#                     "gene_name": "Claudin-17",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   },
#                   {
#                     "gene": "UniProtKB:P56880",
#                     "gene_symbol": "CLDN20",
#                     "gene_name": "Claudin-20",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   },
#                   {
#                     "gene": "UniProtKB:O95471",
#                     "gene_symbol": "CLDN7",
#                     "gene_name": "Claudin-7",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   },
#                   {
#                     "gene": "UniProtKB:C9JDP6",
#                     "gene_symbol": "CLDN25",
#                     "gene_name": "Putative claudin-25",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   },
#                   {
#                     "gene": "UniProtKB:P56746",
#                     "gene_symbol": "CLDN15",
#                     "gene_name": "Claudin-15",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   },
#                   {
#                     "gene": "UniProtKB:A6NM45",
#                     "gene_symbol": "CLDN24",
#                     "gene_name": "Putative claudin-24",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   },
#                   {
#                     "gene": "UniProtKB:P57739",
#                     "gene_symbol": "CLDN2",
#                     "gene_name": "Claudin-2",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   },
#                   {
#                     "gene": "UniProtKB:P56856",
#                     "gene_symbol": "CLDN18",
#                     "gene_name": "Claudin-18",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   },
#                   {
#                     "gene": "UniProtKB:O15551",
#                     "gene_symbol": "CLDN3",
#                     "gene_name": "Claudin-3",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   },
#                   {
#                     "gene": "UniProtKB:Q8N7P3",
#                     "gene_symbol": "CLDN22",
#                     "gene_name": "Claudin-22",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   },
#                   {
#                     "gene": "UniProtKB:O95500",
#                     "gene_symbol": "CLDN14",
#                     "gene_name": "Claudin-14",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   },
#                   {
#                     "gene": "UniProtKB:O14493",
#                     "gene_symbol": "CLDN4",
#                     "gene_name": "Claudin-4",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   },
#                   {
#                     "gene": "UniProtKB:Q9Y5I7",
#                     "gene_symbol": "CLDN16",
#                     "gene_name": "Claudin-16",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   },
#                   {
#                     "gene": "UniProtKB:P56748",
#                     "gene_symbol": "CLDN8",
#                     "gene_name": "Claudin-8",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   },
#                   {
#                     "gene": "UniProtKB:O95484",
#                     "gene_symbol": "CLDN9",
#                     "gene_name": "Claudin-9",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   },
#                   {
#                     "gene": "UniProtKB:P56747",
#                     "gene_symbol": "CLDN6",
#                     "gene_name": "Claudin-6",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   },
#                   {
#                     "gene": "UniProtKB:P78369",
#                     "gene_symbol": "CLDN10",
#                     "gene_name": "Claudin-10",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   },
#                   {
#                     "gene": "UniProtKB:O95832",
#                     "gene_symbol": "CLDN1",
#                     "gene_name": "Claudin-1",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   },
#                   {
#                     "gene": "UniProtKB:Q8N6F1",
#                     "gene_symbol": "CLDN19",
#                     "gene_name": "Claudin-19",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   },
#                   {
#                     "gene": "UniProtKB:O75508",
#                     "gene_symbol": "CLDN11",
#                     "gene_name": "Claudin-11",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN002760867",
#                 "label": "MARVEL DOMAIN-CONTAINING PROTEIN 2",
#                 "terms": [
#                   {
#                     "term_id": "GO:0070830",
#                     "term_label": "bicellular tight junction assembly"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:Q8N4S9",
#                     "gene_symbol": "MARVELD2",
#                     "gene_name": "MARVEL domain-containing protein 2",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   },
#                   {
#                     "gene": "UniProtKB:Q9H607",
#                     "gene_symbol": "OCEL1",
#                     "gene_name": "Occludin/ELL domain-containing protein 1",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               }
#             ],
#             "module_term_label": "tight junction assembly",
#             "nodes_count": 9
#           },
#           {
#             "module_term": "GO:0050807",
#             "nodes": [
#               {
#                 "ptn_id": "PTN007558151",
#                 "label": "V-SET AND TRANSMEMBRANE DOMAIN-CONTAINING PROTEIN 5",
#                 "terms": [
#                   {
#                     "term_id": "GO:1904891",
#                     "term_label": "positive regulation of excitatory synapse assembly"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:A8MXK1",
#                     "gene_symbol": "VSTM5",
#                     "gene_name": "V-set and transmembrane domain-containing protein 5",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN002792796",
#                 "label": "PROTEIN TANC2",
#                 "terms": [
#                   {
#                     "term_id": "GO:0061001",
#                     "term_label": "regulation of dendritic spine morphogenesis"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:Q9HCD6",
#                     "gene_symbol": "TANC2",
#                     "gene_name": "Protein TANC2",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN000088293",
#                 "label": "GLYPICAN-4",
#                 "terms": [
#                   {
#                     "term_id": "GO:1905606",
#                     "term_label": "regulation of presynapse assembly"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:O75487",
#                     "gene_symbol": "GPC4",
#                     "gene_name": "Glypican-4",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN002680016",
#                 "label": "RHO GTPASE-ACTIVATING PROTEIN 44",
#                 "terms": [
#                   {
#                     "term_id": "GO:0061001",
#                     "term_label": "regulation of dendritic spine morphogenesis"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:Q17R89",
#                     "gene_symbol": "ARHGAP44",
#                     "gene_name": "Rho GTPase-activating protein 44",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN008515303",
#                 "label": "E3 UBIQUITIN-PROTEIN LIGASE NEDD4",
#                 "terms": [
#                   {
#                     "term_id": "GO:0050807",
#                     "term_label": "regulation of synapse organization"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:P46934",
#                     "gene_symbol": "NEDD4",
#                     "gene_name": "E3 ubiquitin-protein ligase NEDD4",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN002911882",
#                 "label": "LEUCINE-RICH REPEAT AND FIBRONECTIN TYPE-III DOMAIN-CONTAINING PROTEIN 4",
#                 "terms": [
#                   {
#                     "term_id": "GO:1905606",
#                     "term_label": "regulation of presynapse assembly"
#                   },
#                   {
#                     "term_id": "GO:0099151",
#                     "term_label": "regulation of postsynaptic density assembly"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:Q6PJG9",
#                     "gene_symbol": "LRFN4",
#                     "gene_name": "Leucine-rich repeat and fibronectin type-III domain-containing protein 4",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN002923280",
#                 "label": "SUSHI REPEAT-CONTAINING PROTEIN SRPX2",
#                 "terms": [
#                   {
#                     "term_id": "GO:0051965",
#                     "term_label": "positive regulation of synapse assembly"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:O60687",
#                     "gene_symbol": "SRPX2",
#                     "gene_name": "Sushi repeat-containing protein SRPX2",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN002685921",
#                 "label": "SYNAPSE DIFFERENTIATION-INDUCING GENE PROTEIN 1",
#                 "terms": [
#                   {
#                     "term_id": "GO:0051965",
#                     "term_label": "positive regulation of synapse assembly"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:Q9H7V2",
#                     "gene_symbol": "SYNDIG1",
#                     "gene_name": "Synapse differentiation-inducing gene protein 1",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN000689069",
#                 "label": "LEUCINE-RICH REPEAT-CONTAINING PROTEIN 4B",
#                 "terms": [
#                   {
#                     "term_id": "GO:0051965",
#                     "term_label": "positive regulation of synapse assembly"
#                   },
#                   {
#                     "term_id": "GO:1905606",
#                     "term_label": "regulation of presynapse assembly"
#                   },
#                   {
#                     "term_id": "GO:0099151",
#                     "term_label": "regulation of postsynaptic density assembly"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:Q9NT99",
#                     "gene_symbol": "LRRC4B",
#                     "gene_name": "Leucine-rich repeat-containing protein 4B",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN000689992",
#                 "label": "",
#                 "terms": [
#                   {
#                     "term_id": "GO:0051965",
#                     "term_label": "positive regulation of synapse assembly"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:Q9H5Y7",
#                     "gene_symbol": "SLITRK6",
#                     "gene_name": "SLIT and NTRK-like protein 6",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   },
#                   {
#                     "gene": "UniProtKB:Q96PX8",
#                     "gene_symbol": "SLITRK1",
#                     "gene_name": "SLIT and NTRK-like protein 1",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   },
#                   {
#                     "gene": "UniProtKB:Q9H156",
#                     "gene_symbol": "SLITRK2",
#                     "gene_name": "SLIT and NTRK-like protein 2",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   },
#                   {
#                     "gene": "UniProtKB:O94933",
#                     "gene_symbol": "SLITRK3",
#                     "gene_name": "SLIT and NTRK-like protein 3",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   },
#                   {
#                     "gene": "UniProtKB:O94991",
#                     "gene_symbol": "SLITRK5",
#                     "gene_name": "SLIT and NTRK-like protein 5",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   },
#                   {
#                     "gene": "UniProtKB:Q8IW52",
#                     "gene_symbol": "SLITRK4",
#                     "gene_name": "SLIT and NTRK-like protein 4",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN002792735",
#                 "label": "CORTACTIN-BINDING PROTEIN 2",
#                 "terms": [
#                   {
#                     "term_id": "GO:0050807",
#                     "term_label": "regulation of synapse organization"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:Q8WZ74",
#                     "gene_symbol": "CTTNBP2",
#                     "gene_name": "Cortactin-binding protein 2",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN001020450",
#                 "label": "CALSYNTENIN-1",
#                 "terms": [
#                   {
#                     "term_id": "GO:0051965",
#                     "term_label": "positive regulation of synapse assembly"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:O94985",
#                     "gene_symbol": "CLSTN1",
#                     "gene_name": "Calsyntenin-1",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   },
#                   {
#                     "gene": "UniProtKB:Q9BQT9",
#                     "gene_symbol": "CLSTN3",
#                     "gene_name": "Calsyntenin-3",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   },
#                   {
#                     "gene": "UniProtKB:Q9H4D0",
#                     "gene_symbol": "CLSTN2",
#                     "gene_name": "Calsyntenin-2",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN000652319",
#                 "label": "PROTEIN TANC1",
#                 "terms": [
#                   {
#                     "term_id": "GO:0099175",
#                     "term_label": "regulation of postsynapse organization"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:Q9C0D5",
#                     "gene_symbol": "TANC1",
#                     "gene_name": "Protein TANC1",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN000690490",
#                 "label": "LEUCINE-RICH REPEAT AND FIBRONECTIN TYPE-III DOMAIN-CONTAINING PROTEIN 5",
#                 "terms": [
#                   {
#                     "term_id": "GO:1905606",
#                     "term_label": "regulation of presynapse assembly"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:Q96NI6",
#                     "gene_symbol": "LRFN5",
#                     "gene_name": "Leucine-rich repeat and fibronectin type-III domain-containing protein 5",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN002733372",
#                 "label": "SRC KINASE SIGNALING INHIBITOR 1",
#                 "terms": [
#                   {
#                     "term_id": "GO:0061001",
#                     "term_label": "regulation of dendritic spine morphogenesis"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:Q9C0H9",
#                     "gene_symbol": "SRCIN1",
#                     "gene_name": "SRC kinase signaling inhibitor 1",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN002713640",
#                 "label": "ZIPPER PUTATIVE TUMOR SUPPRESSOR 3-RELATED",
#                 "terms": [
#                   {
#                     "term_id": "GO:0061001",
#                     "term_label": "regulation of dendritic spine morphogenesis"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:O60299",
#                     "gene_symbol": "LZTS3",
#                     "gene_name": "Leucine zipper putative tumor suppressor 3",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN002338293",
#                 "label": "E3 UBIQUITIN-PROTEIN LIGASE MYCBP2",
#                 "terms": [
#                   {
#                     "term_id": "GO:0008582",
#                     "term_label": "regulation of synaptic assembly at neuromuscular junction"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:O75592",
#                     "gene_symbol": "MYCBP2",
#                     "gene_name": "E3 ubiquitin-protein ligase MYCBP2",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               }
#             ],
#             "module_term_label": "regulation of synapse organization",
#             "nodes_count": 17
#           },
#           {
#             "module_term": "GO:0099173",
#             "nodes": [
#               {
#                 "ptn_id": "PTN000022764",
#                 "label": "GEPHYRIN",
#                 "terms": [
#                   {
#                     "term_id": "GO:0072579",
#                     "term_label": "glycine receptor clustering"
#                   },
#                   {
#                     "term_id": "GO:0097112",
#                     "term_label": "gamma-aminobutyric acid receptor clustering"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:Q9NQX3",
#                     "gene_symbol": "GPHN",
#                     "gene_name": "Gephyrin",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN002647993",
#                 "label": "LHFPL TETRASPAN SUBFAMILY MEMBER 4 PROTEIN",
#                 "terms": [
#                   {
#                     "term_id": "GO:0097112",
#                     "term_label": "gamma-aminobutyric acid receptor clustering"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:Q7Z7J7",
#                     "gene_symbol": "LHFPL4",
#                     "gene_name": "LHFPL tetraspan subfamily member 4 protein",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN002762095",
#                 "label": "DEDICATOR OF CYTOKINESIS PROTEIN 10",
#                 "terms": [
#                   {
#                     "term_id": "GO:0060997",
#                     "term_label": "dendritic spine morphogenesis"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:Q96BY6",
#                     "gene_symbol": "DOCK10",
#                     "gene_name": "Dedicator of cytokinesis protein 10",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN000168538",
#                 "label": "NEUROLIGIN 4, ISOFORM F",
#                 "terms": [
#                   {
#                     "term_id": "GO:0097104",
#                     "term_label": "postsynaptic membrane assembly"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:Q8NFZ4",
#                     "gene_symbol": "NLGN2",
#                     "gene_name": "Neuroligin-2",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   },
#                   {
#                     "gene": "UniProtKB:Q9NZ94",
#                     "gene_symbol": "NLGN3",
#                     "gene_name": "Neuroligin-3",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   },
#                   {
#                     "gene": "UniProtKB:Q8N2Q7",
#                     "gene_symbol": "NLGN1",
#                     "gene_name": "Neuroligin-1",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   },
#                   {
#                     "gene": "UniProtKB:Q8NFZ3",
#                     "gene_symbol": "NLGN4Y",
#                     "gene_name": "Neuroligin-4, Y-linked",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   },
#                   {
#                     "gene": "UniProtKB:Q8N0W4",
#                     "gene_symbol": "NLGN4X",
#                     "gene_name": "Neuroligin-4, X-linked",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN000254194",
#                 "label": "PRKCA-BINDING PROTEIN",
#                 "terms": [
#                   {
#                     "term_id": "GO:0097062",
#                     "term_label": "dendritic spine maintenance"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:Q9NRD5",
#                     "gene_symbol": "PICK1",
#                     "gene_name": "PRKCA-binding protein",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN002823788",
#                 "label": "TRANSMEMBRANE PROTEIN 108",
#                 "terms": [
#                   {
#                     "term_id": "GO:0097106",
#                     "term_label": "postsynaptic density organization"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:Q6UXF1",
#                     "gene_symbol": "TMEM108",
#                     "gene_name": "Transmembrane protein 108",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN002808953",
#                 "label": "LEUCINE-RICH REPEAT-CONTAINING PROTEIN 4",
#                 "terms": [
#                   {
#                     "term_id": "GO:0097119",
#                     "term_label": "postsynaptic density protein 95 clustering"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:Q9HBW1",
#                     "gene_symbol": "LRRC4",
#                     "gene_name": "Leucine-rich repeat-containing protein 4",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN002750666",
#                 "label": "DISKS LARGE HOMOLOG 4",
#                 "terms": [
#                   {
#                     "term_id": "GO:0097113",
#                     "term_label": "AMPA glutamate receptor clustering"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:P78352",
#                     "gene_symbol": "DLG4",
#                     "gene_name": "Disks large homolog 4",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN002571420",
#                 "label": "CATENIN DELTA-2",
#                 "terms": [
#                   {
#                     "term_id": "GO:0060997",
#                     "term_label": "dendritic spine morphogenesis"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:Q9UQB3",
#                     "gene_symbol": "CTNND2",
#                     "gene_name": "Catenin delta-2",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               }
#             ],
#             "module_term_label": "postsynapse organization",
#             "nodes_count": 9
#           },
#           {
#             "module_term": "GO:0007416",
#             "nodes": [
#               {
#                 "ptn_id": "PTN000168538",
#                 "label": "NEUROLIGIN 4, ISOFORM F",
#                 "terms": [
#                   {
#                     "term_id": "GO:0097104",
#                     "term_label": "postsynaptic membrane assembly"
#                   },
#                   {
#                     "term_id": "GO:0097105",
#                     "term_label": "presynaptic membrane assembly"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:Q8NFZ4",
#                     "gene_symbol": "NLGN2",
#                     "gene_name": "Neuroligin-2",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   },
#                   {
#                     "gene": "UniProtKB:Q9NZ94",
#                     "gene_symbol": "NLGN3",
#                     "gene_name": "Neuroligin-3",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   },
#                   {
#                     "gene": "UniProtKB:Q8N2Q7",
#                     "gene_symbol": "NLGN1",
#                     "gene_name": "Neuroligin-1",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   },
#                   {
#                     "gene": "UniProtKB:Q8NFZ3",
#                     "gene_symbol": "NLGN4Y",
#                     "gene_name": "Neuroligin-4, Y-linked",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   },
#                   {
#                     "gene": "UniProtKB:Q8N0W4",
#                     "gene_symbol": "NLGN4X",
#                     "gene_name": "Neuroligin-4, X-linked",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN002808953",
#                 "label": "LEUCINE-RICH REPEAT-CONTAINING PROTEIN 4",
#                 "terms": [
#                   {
#                     "term_id": "GO:1904861",
#                     "term_label": "excitatory synapse assembly"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:Q9HBW1",
#                     "gene_symbol": "LRRC4",
#                     "gene_name": "Leucine-rich repeat-containing protein 4",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN002616028",
#                 "label": "KIN OF IRRE-LIKE PROTEIN 3",
#                 "terms": [
#                   {
#                     "term_id": "GO:0007416",
#                     "term_label": "synapse assembly"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:Q8IZU9",
#                     "gene_symbol": "KIRREL3",
#                     "gene_name": "Kin of IRRE-like protein 3",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN000364315",
#                 "label": "SUBFAMILY NOT NAMED",
#                 "terms": [
#                   {
#                     "term_id": "GO:1904071",
#                     "term_label": "presynaptic active zone assembly"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:Q9Y6V0",
#                     "gene_symbol": "PCLO",
#                     "gene_name": "Protein piccolo",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   },
#                   {
#                     "gene": "UniProtKB:Q9UPA5",
#                     "gene_symbol": "BSN",
#                     "gene_name": "Protein bassoon",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN002634572",
#                 "label": "ADHESION G PROTEIN-COUPLED RECEPTOR L3",
#                 "terms": [
#                   {
#                     "term_id": "GO:0007416",
#                     "term_label": "synapse assembly"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:Q9HAR2",
#                     "gene_symbol": "ADGRL3",
#                     "gene_name": "Adhesion G protein-coupled receptor L3",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN002771722",
#                 "label": "CADHERIN-2",
#                 "terms": [
#                   {
#                     "term_id": "GO:0007416",
#                     "term_label": "synapse assembly"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:P19022",
#                     "gene_symbol": "CDH2",
#                     "gene_name": "Cadherin-2",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN000245349",
#                 "label": "ADHESION G-PROTEIN COUPLED RECEPTOR F1",
#                 "terms": [
#                   {
#                     "term_id": "GO:0007416",
#                     "term_label": "synapse assembly"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:Q5T601",
#                     "gene_symbol": "ADGRF1",
#                     "gene_name": "Adhesion G-protein coupled receptor F1",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN000261681",
#                 "label": "F-BOX/SPRY DOMAIN-CONTAINING PROTEIN 1",
#                 "terms": [
#                   {
#                     "term_id": "GO:0060386",
#                     "term_label": "synapse assembly involved in innervation"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:P0C2W1",
#                     "gene_symbol": "FBXO45",
#                     "gene_name": "F-box/SPRY domain-containing protein 1",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN002808820",
#                 "label": "LEUCINE-RICH REPEAT LGI FAMILY MEMBER 2",
#                 "terms": [
#                   {
#                     "term_id": "GO:1904862",
#                     "term_label": "inhibitory synapse assembly"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:Q8N0V4",
#                     "gene_symbol": "LGI2",
#                     "gene_name": "Leucine-rich repeat LGI family member 2",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN000616414",
#                 "label": "CADHERIN-1",
#                 "terms": [
#                   {
#                     "term_id": "GO:0007416",
#                     "term_label": "synapse assembly"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:P12830",
#                     "gene_symbol": "CDH1",
#                     "gene_name": "Cadherin-1",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               }
#             ],
#             "module_term_label": "synapse assembly",
#             "nodes_count": 10
#           },
#           {
#             "module_term": "GO:0007528",
#             "nodes": [
#               {
#                 "ptn_id": "PTN000022764",
#                 "label": "GEPHYRIN",
#                 "terms": [
#                   {
#                     "term_id": "GO:0007529",
#                     "term_label": "establishment of synaptic specificity at neuromuscular junction"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:Q9NQX3",
#                     "gene_symbol": "GPHN",
#                     "gene_name": "Gephyrin",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN000049880",
#                 "label": "UNC-13, ISOFORM E",
#                 "terms": [
#                   {
#                     "term_id": "GO:0007528",
#                     "term_label": "neuromuscular junction development"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:Q8NB66",
#                     "gene_symbol": "UNC13C",
#                     "gene_name": "Protein unc-13 homolog C",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   },
#                   {
#                     "gene": "UniProtKB:O14795",
#                     "gene_symbol": "UNC13B",
#                     "gene_name": "Protein unc-13 homolog B",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   },
#                   {
#                     "gene": "UniProtKB:Q9UPW8",
#                     "gene_symbol": "UNC13A",
#                     "gene_name": "Protein unc-13 homolog A",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN000930213",
#                 "label": "CA2+-CHANNEL-PROTEIN-BETA-SUBUNIT, ISOFORM L",
#                 "terms": [
#                   {
#                     "term_id": "GO:0007528",
#                     "term_label": "neuromuscular junction development"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:P54284",
#                     "gene_symbol": "CACNB3",
# ...
#                 "terms": [
#                   {
#                     "term_id": "GO:0070475",
#                     "term_label": "rRNA base methylation"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:Q9BRP7",
#                     "gene_symbol": "FDXACB1",
#                     "gene_name": "Ferredoxin-fold anticodon-binding domain-containing protein 1",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN000296553",
#                 "label": "18S RRNA (GUANINE-N(7))-METHYLTRANSFERASE-RELATED",
#                 "terms": [
#                   {
#                     "term_id": "GO:0070476",
#                     "term_label": "rRNA (guanine-N7)-methylation"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:O43709",
#                     "gene_symbol": "BUD23",
#                     "gene_name": "Probable 18S rRNA (guanine-N(7))-methyltransferase",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN000515911",
#                 "label": "28S RRNA (CYTOSINE-C(5))-METHYLTRANSFERASE",
#                 "terms": [
#                   {
#                     "term_id": "GO:0070475",
#                     "term_label": "rRNA base methylation"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:Q3KNT7",
#                     "gene_symbol": "NSUN5P1",
#                     "gene_name": "Putative NOL1/NOP2/Sun domain family member 5B",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   },
#                   {
#                     "gene": "UniProtKB:Q63ZY6",
#                     "gene_symbol": "NSUN5P2",
#                     "gene_name": "Putative methyltransferase NSUN5C",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   },
#                   {
#                     "gene": "UniProtKB:Q96P11",
#                     "gene_symbol": "NSUN5",
#                     "gene_name": "28S rRNA (cytosine-C(5))-methyltransferase",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN000515974",
#                 "label": "28S RRNA (CYTOSINE(4447)-C(5))-METHYLTRANSFERASE-RELATED",
#                 "terms": [
#                   {
#                     "term_id": "GO:0070475",
#                     "term_label": "rRNA base methylation"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:P46087",
#                     "gene_symbol": "NOP2",
#                     "gene_name": "Probable 28S rRNA (cytosine(4447)-C(5))-methyltransferase",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               }
#             ],
#             "module_term_label": "rRNA base methylation",
#             "nodes_count": 8
#           },
#           {
#             "module_term": "GO:0000055",
#             "nodes": [
#               {
#                 "ptn_id": "PTN000327285",
#                 "label": "NUCLEAR PORE COMPLEX PROTEIN NUP88",
#                 "terms": [
#                   {
#                     "term_id": "GO:0000055",
#                     "term_label": "ribosomal large subunit export from nucleus"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:Q99567",
#                     "gene_symbol": "NUP88",
#                     "gene_name": "Nuclear pore complex protein Nup88",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN000978434",
#                 "label": "60S RIBOSOMAL EXPORT PROTEIN NMD3",
#                 "terms": [
#                   {
#                     "term_id": "GO:0000055",
#                     "term_label": "ribosomal large subunit export from nucleus"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:Q96D46",
#                     "gene_symbol": "NMD3",
#                     "gene_name": "60S ribosomal export protein NMD3",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN002733488",
#                 "label": "NUCLEOPHOSMIN",
#                 "terms": [
#                   {
#                     "term_id": "GO:0000055",
#                     "term_label": "ribosomal large subunit export from nucleus"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:P06748",
#                     "gene_symbol": "NPM1",
#                     "gene_name": "Nucleophosmin",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN000131787",
#                 "label": "EXPORTIN-1",
#                 "terms": [
#                   {
#                     "term_id": "GO:0000055",
#                     "term_label": "ribosomal large subunit export from nucleus"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:O14980",
#                     "gene_symbol": "XPO1",
#                     "gene_name": "Exportin-1",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN000529705",
#                 "label": "MIDASIN",
#                 "terms": [
#                   {
#                     "term_id": "GO:0000055",
#                     "term_label": "ribosomal large subunit export from nucleus"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:Q9NU22",
#                     "gene_symbol": "MDN1",
#                     "gene_name": "Midasin",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN000296326",
#                 "label": "PROTEIN SDA1 HOMOLOG",
#                 "terms": [
#                   {
#                     "term_id": "GO:0000055",
#                     "term_label": "ribosomal large subunit export from nucleus"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:Q9NVU7",
#                     "gene_symbol": "SDAD1",
#                     "gene_name": "Protein SDA1 homolog",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               }
#             ],
#             "module_term_label": "ribosomal large subunit export from nucleus",
#             "nodes_count": 6
#           },
#           {
#             "module_term": "GO:0031118",
#             "nodes": [
#               {
#                 "ptn_id": "PTN000565614",
#                 "label": "H/ACA RIBONUCLEOPROTEIN COMPLEX SUBUNIT DKC1",
#                 "terms": [
#                   {
#                     "term_id": "GO:0031118",
#                     "term_label": "rRNA pseudouridine synthesis"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:O60832",
#                     "gene_symbol": "DKC1",
#                     "gene_name": "H/ACA ribonucleoprotein complex subunit DKC1",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN008577970",
#                 "label": "21S RRNA PSEUDOURIDINE(2819) SYNTHASE",
#                 "terms": [
#                   {
#                     "term_id": "GO:0000455",
#                     "term_label": "enzyme-directed rRNA pseudouridine synthesis"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:Q8IZ73",
#                     "gene_symbol": "RPUSD2",
#                     "gene_name": "RNA pseudouridylate synthase domain-containing protein 2",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   },
#                   {
#                     "gene": "UniProtKB:Q9UJJ7",
#                     "gene_symbol": "RPUSD1",
#                     "gene_name": "RNA pseudouridylate synthase domain-containing protein 1",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN000329686",
#                 "label": "H/ACA RIBONUCLEOPROTEIN COMPLEX SUBUNIT 3",
#                 "terms": [
#                   {
#                     "term_id": "GO:0031118",
#                     "term_label": "rRNA pseudouridine synthesis"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:Q9NPE3",
#                     "gene_symbol": "NOP10",
#                     "gene_name": "H/ACA ribonucleoprotein complex subunit 3",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN000579935",
#                 "label": "H/ACA RIBONUCLEOPROTEIN COMPLEX SUBUNIT 1",
#                 "terms": [
#                   {
#                     "term_id": "GO:0000454",
#                     "term_label": "snoRNA guided rRNA pseudouridine synthesis"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:Q9NY12",
#                     "gene_symbol": "GAR1",
#                     "gene_name": "H/ACA ribonucleoprotein complex subunit 1",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN000560394",
#                 "label": "H/ACA RIBONUCLEOPROTEIN COMPLEX SUBUNIT 2",
#                 "terms": [
#                   {
#                     "term_id": "GO:0031118",
#                     "term_label": "rRNA pseudouridine synthesis"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:Q9NX24",
#                     "gene_symbol": "NHP2",
#                     "gene_name": "H/ACA ribonucleoprotein complex subunit 2",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               }
#             ],
#             "module_term_label": "rRNA pseudouridine synthesis",
#             "nodes_count": 5
#           },
#           {
#             "module_term": "GO:0000056",
#             "nodes": [
#               {
#                 "ptn_id": "PTN000327285",
#                 "label": "NUCLEAR PORE COMPLEX PROTEIN NUP88",
#                 "terms": [
#                   {
#                     "term_id": "GO:0000056",
#                     "term_label": "ribosomal small subunit export from nucleus"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:Q99567",
#                     "gene_symbol": "NUP88",
#                     "gene_name": "Nuclear pore complex protein Nup88",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN000318455",
#                 "label": "NUCLEOLAR PROTEIN 9",
#                 "terms": [
#                   {
#                     "term_id": "GO:0000056",
#                     "term_label": "ribosomal small subunit export from nucleus"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:Q86U38",
#                     "gene_symbol": "NOP9",
#                     "gene_name": "Nucleolar protein 9",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN002733488",
#                 "label": "NUCLEOPHOSMIN",
#                 "terms": [
#                   {
#                     "term_id": "GO:0000056",
#                     "term_label": "ribosomal small subunit export from nucleus"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:P06748",
#                     "gene_symbol": "NPM1",
#                     "gene_name": "Nucleophosmin",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN000488416",
#                 "label": "PROTEIN LTV1 HOMOLOG",
#                 "terms": [
#                   {
#                     "term_id": "GO:0000056",
#                     "term_label": "ribosomal small subunit export from nucleus"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:Q96GA3",
#                     "gene_symbol": "LTV1",
#                     "gene_name": "Protein LTV1 homolog",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               },
#               {
#                 "ptn_id": "PTN000131787",
#                 "label": "EXPORTIN-1",
#                 "terms": [
#                   {
#                     "term_id": "GO:0000056",
#                     "term_label": "ribosomal small subunit export from nucleus"
#                   }
#                 ],
#                 "leaf_genes": [
#                   {
#                     "gene": "UniProtKB:O14980",
#                     "gene_symbol": "XPO1",
#                     "gene_name": "Exportin-1",
#                     "taxon_id": "9606",
#                     "panther_family": NaN,
#                     "long_id": NaN
#                   }
#                 ]
#               }
#             ],
#             "module_term_label": "ribosomal small subunit export from nucleus",
#             "nodes_count": 5
#           }
#         ],
#         "category_label": "ribosome biogenesis",
#         "module_count": 7
#       }
#     ],
#     "label": "cellular component organization or biogenesis",
#     "category_count": 7
#   }
# ]

# %%
flattened_data = []

for entry in ibd_modules_df.itertuples(index=False):
    category_id = entry.id
    category_count= len(entry.categories)
    for category in entry.categories:
        module_id = category['id']
        module_count = len(category['modules'])
        
        for module in category['modules']:
          
            module_term_id = module['module_term']

            # Process each node
            for node in module.get('nodes', []):
                node_id = node.get('ptn_id')
                node_label = node.get('label')
                
                term_info = [{'term_id': term, 'term_label': terms_df.loc[term, 'label']} for term in node.get('terms', []) if term in terms_df.index]
                gene_info = [genes_df.loc[gene].to_dict() for gene in node.get('leaf_genes', []) if gene in genes_df.index]

                flattened_data.append({
                    'category_id': category_id,
                    'module_id': module_id,
                    'module_term_id': module_term_id,
                    'node_id': node_id,
                    'node_label': node_label,
                    'term_info': term_info,
                    'gene_info': gene_info,
                    'category_count': category_count,
                    'module_count': module_count
                })

flat_df = pd.DataFrame(flattened_data)

# Merge with terms_df for category, module, and module term labels
flat_df = flat_df.merge(terms_df, left_on='category_id', right_on='id', how='left', suffixes=('', '_category')).rename(columns={'label': 'category_label'})
flat_df = flat_df.merge(terms_df, left_on='module_id', right_on='id', how='left', suffixes=('', '_module')).rename(columns={'label': 'module_label'})
flat_df = flat_df.merge(terms_df, left_on='module_term_id', right_on='id', how='left', suffixes=('', '_module_term')).rename(columns={'label': 'module_term_label'})

final_df = flat_df[['category_id',
                    'category_label', 
                    'module_id', 
                    'module_label',
                    'module_term_id', 
                    'module_term_label',
                    'node_id', 
                    'node_label', 
                    'term_info', 
                    'gene_info',
                    'category_count',
                    'module_count']]

final_df
# Out:
#      category_id                                 category_label   module_id  \
# 0     GO:0071840  cellular component organization or biogenesis  GO:0034330
# 1     GO:0071840  cellular component organization or biogenesis  GO:0034330
# 2     GO:0071840  cellular component organization or biogenesis  GO:0034330
# 3     GO:0071840  cellular component organization or biogenesis  GO:0034330
# 4     GO:0071840  cellular component organization or biogenesis  GO:0034330
# ...          ...                                            ...         ...
# 5564  OTHER:0001                       other biological process  GO:0060078
# 5565  OTHER:0001                       other biological process  GO:0060078
# 5566  OTHER:0001                       other biological process  GO:0060078
# 5567  OTHER:0001                       other biological process  GO:0060078
# 5568  OTHER:0001                       other biological process  GO:0060078
#
#                                        module_label module_term_id  \
# 0                        cell junction organization     GO:0120192
# 1                        cell junction organization     GO:0120192
# 2                        cell junction organization     GO:0120192
# 3                        cell junction organization     GO:0120192
# 4                        cell junction organization     GO:0120192
# ...                                             ...            ...
# 5564  regulation of postsynaptic membrane potential     GO:0060078
# 5565  regulation of postsynaptic membrane potential     GO:0060078
# 5566  regulation of postsynaptic membrane potential     GO:0060078
# 5567  regulation of postsynaptic membrane potential     GO:0060078
# 5568  regulation of postsynaptic membrane potential     GO:0060078
#
#                                   module_term_label       node_id  \
# 0                           tight junction assembly  PTN007679700
# 1                           tight junction assembly  PTN002698193
# 2                           tight junction assembly  PTN002731222
# 3                           tight junction assembly  PTN000462700
# 4                           tight junction assembly  PTN004555956
# ...                                             ...           ...
# 5564  regulation of postsynaptic membrane potential  PTN001806145
# 5565  regulation of postsynaptic membrane potential  PTN000436343
# 5566  regulation of postsynaptic membrane potential  PTN000751216
# 5567  regulation of postsynaptic membrane potential  PTN002823877
# 5568  regulation of postsynaptic membrane potential  PTN002698114
#
#                                        node_label  \
# 0                                    PATJ HOMOLOG
# 1       LIPOLYSIS-STIMULATED LIPOPROTEIN RECEPTOR
# 2                                   PROTEIN POF1B
# 3        FERM AND PDZ DOMAIN-CONTAINING PROTEIN 2
# 4              MARVEL DOMAIN-CONTAINING PROTEIN 3
# ...                                           ...
# 5564        PRO-FMRFAMIDE-RELATED NEUROPEPTIDE FF
# 5565  GAMMA-AMINOBUTYRIC ACID RECEPTOR ALPHA-LIKE
# 5566                   NMDA RECEPTOR 2, ISOFORM C
# 5567                INHIBITORY SYNAPTIC FACTOR 2A
# 5568                 INHIBITORY SYNAPTIC FACTOR 1
#
#                                               term_info  \
# 0     [{'term_id': 'GO:0120192', 'term_label': 'tigh...
# 1     [{'term_id': 'GO:1904274', 'term_label': 'tric...
# 2     [{'term_id': 'GO:0070830', 'term_label': 'bice...
# 3     [{'term_id': 'GO:0070830', 'term_label': 'bice...
# 4     [{'term_id': 'GO:0070830', 'term_label': 'bice...
# ...                                                 ...
# 5564  [{'term_id': 'GO:0060079', 'term_label': 'exci...
# 5565  [{'term_id': 'GO:0060078', 'term_label': 'regu...
# 5566  [{'term_id': 'GO:0060079', 'term_label': 'exci...
# 5567  [{'term_id': 'GO:0060080', 'term_label': 'inhi...
# 5568  [{'term_id': 'GO:0060080', 'term_label': 'inhi...
#
#                                               gene_info  category_count  \
# 0     [{'gene': 'UniProtKB:O75970', 'gene_symbol': '...               7
# 1     [{'gene': 'UniProtKB:Q86X29', 'gene_symbol': '...               7
# 2     [{'gene': 'UniProtKB:Q8WVV4', 'gene_symbol': '...               7
# 3     [{'gene': 'UniProtKB:Q68DX3', 'gene_symbol': '...               7
# 4     [{'gene': 'UniProtKB:Q96A59', 'gene_symbol': '...               7
# ...                                                 ...             ...
# 5564  [{'gene': 'UniProtKB:O15130', 'gene_symbol': '...              12
# 5565  [{'gene': 'UniProtKB:P47869', 'gene_symbol': '...              12
# 5566  [{'gene': 'UniProtKB:Q14957', 'gene_symbol': '...              12
# 5567  [{'gene': 'UniProtKB:A6NMK8', 'gene_symbol': '...              12
# 5568  [{'gene': 'UniProtKB:Q2T9L4', 'gene_symbol': '...              12
#
#       module_count
# 0                7
# 1                7
# 2                7
# 3                7
# 4                7
# ...            ...
# 5564             1
# 5565             1
# 5566             1
# 5567             1
# 5568             1
#
# [5569 rows x 12 columns]

# %%
ibd_json = final_df.to_json(orient="records", default_handler=None)
json_str = json.loads(ibd_json)
write_to_json(json_str, ospath.join(clean_ibd_modukes_fp), indent=2)
#pprint.pprint(json_str)

# %%
filtered_results = final_df[final_df['module_id'] =="GO:0120192"]

filtered_results

# %%
annos_df = pd.read_json(annotations_fp)[:10]
annos_df = annos_df.merge(genes_df[
    ['taxon_id', 
     'taxon_label', 
     'taxon_abbr' , 
     'coordinates_chr_num',
     'coordinates_start',
     'coordinates_end',
     'coordinates_strand']], how='left', left_on="gene", right_index=True)
#anno_json = annos_df.to_json(orient="records", default_handler=None)
#json_str = json.loads(anno_json)
#write_to_json(json_str, ospath.join(sample_annotations_fp))
#pprint.pprint(json_str)
annos_df

# %%
# %%time

annos_df = pd.read_json(annotations_fp)[:100]
annos_df = annos_df.merge(genes_df[['gene_symbol',
     'gene_name','taxon_id', 'taxon_label',
                                    'taxon_abbr', 
                                    'coordinates_chr_num','coordinates_start','coordinates_end','coordinates_strand']], how='left', left_on="gene", right_index=True)
#annos_df['aspect'] = annos_df['term'].apply(lambda x: get_pd_row(terms_df, x)['aspect'])
annos_df

# %%
# %%time

def count_evidence(evidences):
    return len(evidences)

def generate_id(row):
    return f'{row["gene"]}_{row["_id"]}'

def get_groups(evidences):
    groups = set()
    for evidence in evidences:
        for group in evidence['groups']:
            groups.add(group)
            
    return list(groups)
    
annos_df = pd.read_json(annotations_fp)[:5]
annos_df = annos_df.merge(genes_df[
    ['gene_symbol',
     'gene_name',
     'taxon_id', 
     'taxon_label', 
     'taxon_abbr' , 
     'coordinates_chr_num',
     'coordinates_start',
     'coordinates_end',
     'coordinates_strand']], how='left', left_on="gene", right_index=True)
annos_df['aspect'] = annos_df['term'].apply(lambda x: get_pd_row(terms_df, x)['aspect'])
annos_df['term'] = annos_df['term'].apply(lambda x: get_pd_row(terms_df, x))
annos_df['term_type'] = annos_df['term'].apply(lambda x: term_type(x))
annos_df['slim_terms'] = annos_df['slim_terms'].apply(lambda x: spread_terms(terms_df, x))
annos_df['qualifier'] = annos_df['qualifier'].str.replace('_', ' ')
annos_df['evidence'] = annos_df.apply(lambda x: get_evidence(articles_df, genes_df, x),axis=1)
annos_df['evidence_type'] = annos_df.apply(lambda x: get_evidence_type(x), axis=1)
annos_df['groups'] = annos_df['evidence'].apply(lambda x: get_groups(x))
annos_df['evidence_count'] = annos_df['evidence'].apply(lambda x: count_evidence(x))


   
anno_json = annos_df.to_json(orient="records", default_handler=None)
json_str = json.loads(anno_json)
#pprint.pprint(json_str)
write_to_json(json_str, ospath.join('.', clean_annotations_fp))
annos_df

# %%
annos_df['_id'] = annos_df.index
annos_df['_id'] = annos_df.apply(lambda x: generate_id(x), axis=1)
annos_df

# %%
# %%time

def term_display_id(term):
    return term['id'] if term['id'].startswith("GO") else ''

fields=['gene', 'term']
export_annos_df = pd.read_json(annotations_fp)[:5]
export_annos_df = export_annos_df[fields]
export_annos_df = export_annos_df.merge(genes_df[
    ['gene_symbol',
     'gene_name']], how='left', left_on="gene", right_index=True)
export_annos_df['term'] = export_annos_df['term'].apply(lambda x: get_pd_row(terms_df, x))
export_annos_df['term_id'] = export_annos_df['term'].apply(lambda x: term_display_id(x))
export_annos_df['term_label'] = export_annos_df['term'].apply(lambda x: x['label'])
export_annos_df = export_annos_df.drop(columns=['term'])

compression_opts = dict(method='zip',
                        archive_name='annotations.csv')  
export_annos_df.to_csv(ospath.join('.', export_annotations_csv_fp), index=False, compression=compression_opts)  
   
    
export_anno_json = export_annos_df.to_json(orient="records", default_handler=None)
json_str = json.loads(export_anno_json)
#pprint.pprint(json_str)
write_to_json(json_str, ospath.join('.', export_annotations_json_fp), zip=True)


    
export_annos_df

# %%
# %%time
    
old_annos_df = pd.read_json(old_annotations_fp)
old_annos_df = old_annos_df.merge(genes_df[
    [ 'taxon_id', 
     'taxon_label', 
     'taxon_abbr' , 
     'coordinates_chr_num',
     'coordinates_start',
     'coordinates_end',
     'coordinates_strand']], how='left', left_on="gene", right_index=True)

   
anno_json = old_annos_df.to_json(orient="records", default_handler=None)
json_str = json.loads(anno_json)
#pprint.pprint(json_str)
write_to_json(json_str, ospath.join('.', old_clean_annotations_fp))
old_annos_df

# %%
annos_df['evidence_type'] = annos_df.apply(lambda x: get_evidence_type(x), axis=1)
annos_df[annos_df['evidence_type']=='direct']

# %%
print(dict(annos_df.iloc[1]))

# %%
clean_annos_df = pd.read_json(clean_annotations_fp)
clean_annos_df

# %%
old_clean_annos_df = pd.read_json(old_clean_annotations_fp)

# %%
filtered_terms = terms_df[terms_df['is_goslim']==True]
filtered_terms

# %%
def add_terms():
    results = list()
    for n in range(0, len(human_df) -1):
        index = random.randrange(0, len(filtered_terms))
        results.append(dict(filtered_terms.iloc[index]))
    
    return results

count = 1

def add_gene():
    return human_df.iloc[count]['gene']

    
                            
#add_terms()

#ann2_df = pd.DataFrame.from_dict(add_terms())
ann2_df

ann3 = human_df.agg('-'.join, axis=1)
ann2_df

add_gene()
ann2_df['gene'] = ann2_df['id'].apply(lambda x: add_gene())
ann2_df

json_chunk = ann2_df.to_json(orient="records", default_handler=None)
json_str = json.loads(json_chunk)

write_to_json(json_str, 'out.json')

# %%
class CustomJSONizer(json.JSONEncoder):
    def default(self, obj):
        return super().encode(bool(obj)) \
            if isinstance(obj, np.bool_) \
            else super().default(obj)
    
def count_unique_terms(annos_df):
    terms = set()
    for term in list(annos_df['term']):
        terms.add(term['id'])
    
    return list(terms)

#count_uniq = count_unique_terms()
#write_to_json(count_uniq, filtered_terms_fp, cls=CustomJSONizer)
#print(len(count_uniq))

def count_unique_slim_terms(annos_df):
    terms = set()
        
    for s_terms in list(annos_df['slim_terms']):
        for term in s_terms:
            terms.add(term['id'])
            
    return list(terms)

#count_uniq = count_unique_slim_terms()
#write_to_json(count_uniq, filtered_slim_terms_fp, cls=CustomJSONizer)
#print(count_uniq)
def count_unique_refs(annos_df):
    refs = set()
        
    for evidences in list(annos_df['evidence']):
        for evidence in evidences:
            for ref in evidence['references']:
                if ref is not None:
                    refs.add(ref['pmid'])
            
    return list(refs)

def count_unique_withs(annos_df):
    gene = set()
    gene_name=set()
        
    for evidences in list(annos_df['evidence']):
        for evidence in evidences:
            gene.add(evidence['with_gene_id']['gene'])
            
    return list(gene)

len(count_unique_refs(clean_annos_df))

# %%
scalar_cols = {
    'gene', 
    'gene_symbol',
    'gene_name',
    'taxon_id', 
    'taxon_label', 
    'taxon_abbr', 
    'coordinates_chr_num', 
    'coordinates_start', 
    'coordinates_end', 
    'aspect', 
    'evidence_type'
}
    

stats = {k: len(clean_annos_df[k].unique()) for k in scalar_cols }

stats['terms']=len(count_unique_terms(clean_annos_df))
stats['slim_terms']=len(count_unique_slim_terms(clean_annos_df))
stats['references']=len(count_unique_refs(clean_annos_df))
stats['with_gene']=len(count_unique_withs(clean_annos_df))
stats_df = pd.DataFrame.from_dict(stats, orient ='index', columns=['Unique Count'])
stats_df
#clean_annos_df['evidence_type'].unique()

# %%
scalar_cols = {
    'gene', 
    'gene_symbol',
    'gene_name',
    'taxon_id', 
    'taxon_label', 
    'taxon_abbr', 
    'coordinates_chr_num', 
    'coordinates_start', 
    'coordinates_end', 
}
    

stats = {k: len(old_clean_annos_df[k].unique()) for k in scalar_cols }

stats_df = pd.DataFrame.from_dict(stats, orient ='index', columns=['Unique Count'])
stats_df
#clean_annos_df['evidence_type'].unique()

# %%
unique_genes = clean_annos_df.drop_duplicates(subset=['gene', 'gene_symbol', 'gene_name'])
unique_genes = unique_genes[['gene', 'gene_symbol', 'gene_name']]
unique_genes = unique_genes[~unique_genes.duplicated(subset=['gene_symbol'])]
duplicate_genes = unique_genes[unique_genes.duplicated(subset=['gene'])]
duplicate_genes = duplicate_genes[['gene']]
res = unique_genes[unique_genes['gene'].isin(list(duplicate_genes['gene']))]
res = res.sort_values(by=['gene'])
res.to_csv(duplicate_gene_fp)
res

# %%
unique_genes = clean_annos_df.drop_duplicates(subset=['gene'])
unique_genes = unique_genes.sort_values(by=['gene_name'])
#unique_genes.to_csv(duplicate_gene_fp)
unique_genes = unique_genes[['gene', 'gene_symbol', 'gene_name']]
duplicate_genes = unique_genes[unique_genes.duplicated(subset=['gene_name'])]
duplicate_genes[duplicate_genes['gene_name']=='Uncharacterized protein (Fragment)']
#unique_genes.to_csv('./downloads/genes_symb.csv')

# %%
unique_genes = old_clean_annos_df.drop_duplicates(subset=['gene'])
unique_genes = unique_genes.sort_values(by=['gene_name'])
#unique_genes.to_csv(duplicate_gene_fp)
unique_genes = unique_genes[['gene', 'gene_symbol', 'gene_name']]
duplicate_genes_2 = unique_genes[unique_genes.duplicated(subset=['gene_symbol'])]
duplicate_genes_2
#unique_genes.to_csv('./downloads/genes_symb.csv')

# %%
res = duplicate_genes[~duplicate_genes['gene_symbol'].isin(list(duplicate_genes_2['gene_symbol']))]
res

# %%
gene_df.loc('UniProtKB:X6R8D5')

# %%
clean_annos_df['term_label'] = clean_annos_df['term'].apply(lambda x: x['label'])
unknown_cc_df = clean_annos_df[clean_annos_df['term_label']=='Unknown cellular component']
unique_genes = unknown_cc_df.drop_duplicates(subset=['gene_name'])
unique_genes

# %%
clean_annos_df = pd.read_json(clean_annotations_fp)[:100]
clean_annos_df =  clean_annos_df.drop(['evidence'], axis=1)
clean_annos_df

# %%
def uniquify_term(series):
    unique_terms = {}
    for item in series:
        if isinstance(item, dict):
            unique_terms[item['id']] = item
    return list(unique_terms.values())

def uniquify_slim_terms(series):
    unique_terms = {}
    for item_list in series:
        if isinstance(item_list, list):
            for item in item_list:
                unique_terms[item['id']] = item
    return list(unique_terms.values())

genes_df = (
    clean_annos_df.groupby('gene')
    .agg({
        'term': uniquify_term,
        'slim_terms': uniquify_slim_terms
    })
    .reset_index()
)

anno_json = genes_df.to_json(orient="records", default_handler=None)
json_str = json.loads(anno_json)
#pprint.pprint(json_str)
write_to_json(json_str, ospath.join('.', genes_annotations_fp), indent=2)

genes_df

# %%
def uniquify_term(series, evidence_series):
    unique_terms = {}
    term_counts = {}
    duplicates = []

    for idx, item in enumerate(series):
        if isinstance(item, dict):
            term_id = item['id']
            term = item.copy()  
            term.pop('is_goslim', None) 
            term['evidence_type'] = evidence_series.iloc[idx] 
            
            if term_id in term_counts:
                term_counts[term_id] += 1
                duplicates.append(term)
            else:
                term_counts[term_id] = 1

            unique_terms[term_id] = term
            
    return (list(unique_terms.values()), duplicates)


def uniquify_slim_terms(series, evidence_series):
    unique_terms = {}
    for idx, item_list in enumerate(series):
        if isinstance(item_list, list):
            for item in item_list:
                term = item.copy() 
                term.pop('is_goslim', None)
                term['evidence_type'] = evidence_series.iloc[idx]  # add the evidence_type
                unique_terms[term['id']] = term
    return list(unique_terms.values())


genes_df = clean_annos_df.groupby('gene').apply(lambda group: pd.Series({
    'terms': uniquify_term(group['term'], group['evidence_type'])[0],
    'duplicated_terms': uniquify_term(group['term'], group['evidence_type'])[1],  
    'slim_terms': uniquify_slim_terms(group['slim_terms'], group['evidence_type'])
})).reset_index()

anno_json = genes_df.to_json(orient="records", default_handler=None)
json_str = json.loads(anno_json)
#pprint.pprint(json_str)
write_to_json(json_str, ospath.join('.', genes_annotations_fp), indent=2)

genes_df

# %%
def uniquify_term(series, evidence_series):
    unique_terms = {}
    term_counts = {}

    for idx, item in enumerate(series):
        if isinstance(item, dict):
            term_id = item['id']
            term = item.copy()  
            term.pop('is_goslim', None) 
            term['evidence_type'] = evidence_series.iloc[idx]  # add the evidence_type
            
            if term_id in term_counts:
                raise ValueError(f"Duplicate term found: {term}")
            else:
                term_counts[term_id] = 1

            unique_terms[term_id] = term
            
    return list(unique_terms.values())


def uniquify_slim_terms(series, evidence_series):
    unique_terms = {}
    for idx, item_list in enumerate(series):
        if isinstance(item_list, list):
            for item in item_list:
                term = item.copy() 
                term.pop('is_goslim', None)
                term['evidence_type'] = evidence_series.iloc[idx]  # add the evidence_type
                unique_terms[term['id']] = term
    return list(unique_terms.values())

columns_to_extract = [
    'gene_name',
    'taxon_id',
    'taxon_label',
    'taxon_abbr',
    'panther_family',
    'long_id',
    'coordinates_chr_num',
    'coordinates_start',
    'coordinates_end',
    'gene_symbol'
]

def group_terms(group):
    unique_terms = uniquify_term(group['term'], group['evidence_type'])
    slim_terms = uniquify_slim_terms(group['slim_terms'], group['evidence_type'])
    return pd.Series({
         **{col: group[col].iloc[0] for col in columns_to_extract},
        'terms': unique_terms,
        'slim_terms': slim_terms,
        'terms_count': len(unique_terms)
    })

genes_df = clean_annos_df.groupby('gene').apply(group_terms).reset_index()
genes_df = genes_df.sort_values(by='terms_count', ascending=False).reset_index(drop=True)


anno_json = genes_df.to_json(orient="records", default_handler=None)
json_str = json.loads(anno_json)
#pprint.pprint(json_str)
write_to_json(json_str, ospath.join('.', genes_annotations_fp), indent=2)

genes_df
